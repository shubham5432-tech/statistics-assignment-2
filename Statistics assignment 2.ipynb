# %% [markdown]
# #Theory questions:-
#
# ### 1. What is a random variable in probability theory?
#
# A **random variable** is a numerical value assigned to the outcome of a random experiment.
#
# It acts like a function that maps outcomes of a sample space to real numbers.
#
# There are two main types:
# - **Discrete random variable**: Takes specific, countable values (e.g., number of heads in coin tosses).
# - **Continuous random variable**: Can take any value in a continuous range (e.g., height, weight).
#
# #### Example:
# - Tossing a coin twice:
#   - Possible outcomes: HH, HT, TH, TT
#   - Define a random variable X = number of heads
#   - Then X can be 0, 1, or 2 depending on the result.
# ---
# ### 2. What are the types of random variables?
#
# There are two main types of random variables:
#
# #### 1. **Discrete Random Variable**
# - Takes on a **finite or countably infinite** number of values.
# - Common in situations where outcomes are counted.
# - Example: Number of students in a class, number of heads in 3 coin tosses.
#
# #### 2. **Continuous Random Variable**
# - Can take on **any value within a continuous range**.
# - Values are usually measured, not counted.
# - Example: Height, weight, time, temperature.
#
# ---
#
# #### 📌 Key Difference:
# - Discrete values can be **listed** (like 0, 1, 2…)
# - Continuous values are on a **scale** and often require intervals (like 1.52, 2.73, etc.)
# ---
# ### 3. What is the difference between discrete and continuous distributions?
#
# | Feature                      | Discrete Distribution                            | Continuous Distribution                          |
# |-----------------------------|--------------------------------------------------|--------------------------------------------------|
# | **Definition**              | Deals with **countable** outcomes                | Deals with **uncountable/infinite** outcomes     |
# | **Type of Variable**        | Discrete random variable                         | Continuous random variable                       |
# | **Probability at a point**  | Can assign exact probability to a value          | Probability at an exact point is zero            |
# | **Example Distributions**   | Binomial, Poisson, Bernoulli                     | Normal, Uniform, Exponential                     |
# | **Example Outcome**         | Number of emails received in an hour (0, 1, 2…)  | Time taken to respond to an email (2.4 sec...)   |
#
# ---
#
# #### 📌 Summary:
# - **Discrete distributions** are for things you **count** (like steps).
# - **Continuous distributions** are for things you **measure** (like height or time).
#
# A **Probability Distribution Function (PDF)** describes how probabilities are distributed over the values of a **random variable**.
#
# ---
#
# ### 4. What are Probability Distribution Functions (PDF)?
#
# #### 📌 Types of PDFs:
#
# 1. **For Discrete Random Variables**:
#    It's called a **Probability Mass Function (PMF)**.
#    - It gives the probability for each **exact** value.
#    - Example: Rolling a fair die — each face (1–6) has P = 1/6.
#
# 2. **For Continuous Random Variables**:
#    It’s called a **Probability Density Function (PDF)**.
#    - It gives a **density**, not direct probability.
#    - Probability is calculated over an **interval**, not a single point.
#    - The **area under the curve** between two points gives the probability.
#
# ---
#
# #### ✏️ Key Properties:
# - For a continuous PDF, total area under the curve = 1.
# - A PDF **is not a probability**, but the integral (area) over a range is.
# ---
# ### 5. How do Cumulative Distribution Functions (CDF) differ from Probability Distribution Functions (PDF)?
#
# #### 📘 PDF (Probability Distribution Function)
# - Applies to **continuous** random variables.
# - Describes the **density** of probabilities over a range.
# - Cannot be used directly to find the probability at a single point (it's zero for continuous variables).
# - To find probability over a range, integrate the PDF.
#
# #### 📘 CDF (Cumulative Distribution Function)
# - Applies to **both discrete and continuous** variables.
# - Represents the **probability that a random variable X is less than or equal to a value x**:
#   \[
#   CDF(x) = P(X \leq x)
#   \]
# - Always increases from 0 to 1.
# - For continuous variables, CDF is the **area under the PDF curve** from -∞ to x.
#
# ---
#
# ### 🔄 Key Differences:
#
# | Feature              | PDF                                        | CDF                                        |
# |---------------------|--------------------------------------------|--------------------------------------------|
# | Meaning             | Probability **density** at a point         | Cumulative probability up to a point       |
# | Value Range         | Can be greater than 1 (as density)         | Always between 0 and 1                     |
# | Area or Height      | Height of the curve                        | Area under the curve up to x               |
# | Type                | Only for continuous distributions          | For both continuous and discrete           |
#
# ---
# ### 6. What is a Discrete Uniform Distribution?
#
# A **discrete uniform distribution** is a type of probability distribution where **all possible outcomes are equally likely**.
#
# ---
#
# ### 📘 Definition:
# If a random variable **X** can take **n** distinct values \( x_1, x_2, ..., x_n \), and each has equal probability:
#
# \[
# P(X = x_i) = \frac{1}{n} \quad \text{for all } i
# \]
#
# ---
#
# ### 🎲 Example:
# Tossing a fair die:
# - Outcomes = {1, 2, 3, 4, 5, 6}
# - Each outcome has probability = 1/6
#
# ---
#
# ### ✅ Key Characteristics:
# - **Equal probabilities** for all outcomes.
# - **Finite** number of possible values.
# - Common in simple games of chance.
# ---
# ### 7. What are the Key Properties of a Bernoulli Distribution?
#
# A **Bernoulli distribution** is a discrete probability distribution for a random experiment that has only **two possible outcomes**:
# - Success (1) with probability **p**
# - Failure (0) with probability **1 - p**
#
# ---
#
# ### ✅ Properties:
#
# - **Random Variable X**: Takes value 1 (success) or 0 (failure)
# - **Probability Mass Function (PMF)**:
#   \[
#   P(X = x) = p^x (1 - p)^{1 - x}, \quad \text{for } x \in \{0,1\}
#   \]
# - **Mean (Expected Value)**:
#   \[
#   E[X] = p
#   \]
# - **Variance**:
#   \[
#   Var(X) = p(1 - p)
#   \]
#
# ---
#
# ### 🧠 Example:
# - Tossing a coin:
#   - Success = Head (1), Failure = Tail (0)
#   - If coin is fair, then p = 0.5
# ---
#
# ### 8. What is the Binomial Distribution, and How Is It Used in Probability?
#
# The **Binomial Distribution** models the number of **successes** in a fixed number of **independent Bernoulli trials**, where each trial has two outcomes (success or failure).
#
# ---
#
# ### ✅ Key Parameters:
# - **n**: Number of trials
# - **p**: Probability of success in each trial
# - **X**: Random variable representing the number of successes (X ∈ {0, 1, ..., n})
#
# ---
#
# ### 📘 Probability Mass Function (PMF):
# $$
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# $$
# Where:
#  $$
#  ( \binom{n}{k} \) = "n choose k" = number of ways to choose k successes
#  $$
#
# ---
#
# ### 📊 Common Use Cases:
# - Number of heads in 10 coin tosses
# - Number of correct answers in a multiple-choice quiz
# - Number of defective items in a batch
# ---
# ### 9. What is the Poisson Distribution and Where Is It Applied?
#
# The **Poisson distribution** is a discrete probability distribution that models the number of **events occurring in a fixed interval** of time or space, **given the average number of events (λ)** and assuming the events occur independently.
#
# ---
#
# ### ✅ Key Parameter:
# - **λ (lambda)**: Average rate (mean) of occurrences per interval (e.g., 5 calls per hour)
#
# ---
#
# ### 📘 Probability Mass Function (PMF):
#
# $$
# P(X = k) = \frac{e^{-\lambda} \lambda^k}{k!}
# $$
#
# Where:
# - **k** = number of events (0, 1, 2, ...)
# - **λ** = average rate
# - **e** ≈ 2.71828
#
# ---
#
# ### 📌 Common Applications:
# - Number of customer arrivals per hour at a store
# - Number of emails received in a day
# - Number of defects per unit area in manufacturing
# - Earthquakes in a region per year
#
# ---
#
# ### 📊 Characteristics:
# - Discrete, non-negative integer values
# - Mean = Variance = λ
# - Assumes events happen **independently** and **randomly**
# ---
# ### 10. What is a Continuous Uniform Distribution?
#
# A **continuous uniform distribution** is a type of probability distribution where **every value within a specified continuous interval [a, b] is equally likely**.
#
# ---
#
# ### 📘 Probability Density Function (PDF):
#
# \[
# f(x) =
# \begin{cases}
# \frac{1}{b - a} & \text{for } a \leq x \leq b \\
# 0 & \text{otherwise}
# \end{cases}
# \]
#
# ---
#
# ### ✅ Key Characteristics:
#
# - All outcomes in the interval \([a, b]\) have **equal probability density**
# - The PDF is **flat** (constant height)
# - Mean:
#   $$
#   \mu = \frac{a + b}{2}
#   $$
# - Variance:
#   $$
#   \sigma^2 = \frac{(b - a)^2}{12}
#   $$
# ---
#
# ### 📊 Example Use Cases:
# - Picking a random number between 10 and 20
# - Modeling random delays or wait times within a known range
# ---
# ### 11. What Are the Characteristics of a Normal Distribution?
#
# The **normal distribution** (also called the Gaussian distribution) is one of the most important and widely used continuous probability distributions in statistics.
#
# ---
#
# ### ✅ Key Characteristics:
#
# 1. **Bell-Shaped Curve**
#    - Symmetrical around the mean (μ)
#
# 2. **Mean = Median = Mode**
#    - All three measures of central tendency are equal
#
# 3. **Defined by Two Parameters**
#    - **μ (mean)**: determines the center
#    - **σ (standard deviation)**: controls the spread
#
# 4. **Empirical Rule (68-95-99.7 Rule)**
#    - ~68% of data falls within ±1σ
#    - ~95% within ±2σ
#    - ~99.7% within ±3σ
#
# 5. **Asymptotic**
#    - Tails approach but never touch the x-axis
#
# 6. **Area Under the Curve = 1**
#    - Represents total probability
#
# 7. **Used in the Central Limit Theorem**
#    - Many real-world processes approximate a normal distribution due to CLT
#
# ---
#
# ### 🧠 Examples:
# - Human height, weight, IQ scores
# - Measurement errors
# - Test scores in large populations
# ---
# ### 12. What is the Standard Normal Distribution, and Why Is It Important?
#
# The **Standard Normal Distribution** is a special case of the normal distribution where:
#
# - **Mean (μ) = 0**
# - **Standard deviation (σ) = 1**
#
# It is denoted by **Z**, and the random variable that follows this distribution is called a **Z-score**.
#
# ---
#
# ### ✅ Why Is It Important?
#
# 1. **Universal Reference**
#    - Any normal distribution can be converted into a standard normal using Z-scores:
#      \[
#      Z = \frac{X - \mu}{\sigma}
#      \]
#
# 2. **Simplifies Calculations**
#    - Tables and calculators use Z-distribution to compute probabilities and critical values.
#
# 3. **Used in Hypothesis Testing**
#    - Z-values are critical in determining significance in statistical tests.
#
# 4. **Foundation for Confidence Intervals**
#    - Z-distribution helps define boundaries for confidence levels like 90%, 95%, and 99%.
#
# 5. **Common in CLT Applications**
#    - Due to the Central Limit Theorem, sample means approach a normal distribution → often standardized.
# ---
# ### 13. What is the Central Limit Theorem (CLT), and Why Is It Critical in Statistics?
#
# The **Central Limit Theorem (CLT)** is a fundamental concept in statistics that explains how the distribution of sample means becomes **approximately normal**, regardless of the shape of the original population distribution, **as the sample size becomes large**.
#
# ---
#
# ### ✅ Formal Statement:
# If you take many random samples (size **n**) from any population (with mean μ and standard deviation σ), then:
#
# - The distribution of the **sample means** approaches a **normal distribution**
# - The mean of the sampling distribution is **μ**
# - The standard deviation of the sampling distribution is **σ / √n**
#
# This happens when **n is sufficiently large** (usually n ≥ 30).
#
# ---
#
# ### 📌 Why Is It Critical?
#
# 1. **Enables Normal Approximation**
#    - Even if the population is not normally distributed, sample means will be approximately normal.
#
# 2. **Foundation of Inferential Statistics**
#    - Used to create confidence intervals and conduct hypothesis tests.
#
# 3. **Allows Use of Z-Statistics**
#    - Because sampling distribution becomes normal, we can use standard normal tables for analysis.
#
# 4. **Real-World Applications**
#    - Estimating averages like exam scores, customer spending, wait times, etc.
#
# ---
#
# ### 🧠 Example:
#
# Suppose we measure the height of 100 different samples of students, each of size 50. Even if individual heights are skewed, the **average height of each sample** will form a **normal distribution**.
#
# ---
# ### 14. How Does the Central Limit Theorem Relate to the Normal Distribution?
#
# The **Central Limit Theorem (CLT)** explains **why** the **normal distribution is so commonly used** in statistics — even when the original data is **not normally distributed**.
#
# ---
#
# ### ✅ Key Relationship:
#
# - As per CLT, when you:
#   - Take many **random samples** (with size n)
#   - From **any population** (regardless of its distribution)
# - The distribution of the **sample means** will approach a **normal distribution** as **n increases**.
#
# $$
# \text{Sampling distribution of the sample mean } \to \text{Normal distribution}
# $$
#
# ---
#
# ### 📌 Why This Matters:
#
# 1. **Justifies the Use of Z-scores and Confidence Intervals**
#    - Since sample means are normally distributed, we can apply standard normal techniques.
#
# 2. **Applies to Non-Normal Populations**
#    - Works even when the original population is skewed or uniform.
#
# 3. **Forms the Basis of Hypothesis Testing**
#    - Especially for tests involving means and proportions.
#
# ---
# ### 15. What is the Application of Z Statistics in Hypothesis Testing?
#
# **Z-statistics** (or **Z-scores**) are used in **hypothesis testing** to determine whether a sample result is significantly different from a known population parameter, assuming the data follows a normal distribution.
#
# ---
#
# ### ✅ Common Applications:
#
# 1. **Testing a Population Mean**
#   $$
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
#
# $$
# \bar{X} : \text{ Sample mean}
# $$
#
# $$
# \mu : \text{ Population mean}
# $$
#
# $$
# \sigma : \text{ Population standard deviation}
# $$
#
# $$
# n : \text{ Sample size}
# $$
#
# 2. **Comparing Sample and Population**
#    To check whether a sample is likely drawn from a population with a known mean.
#
# 3. **Used in One-Tailed or Two-Tailed Tests**
#    - **One-tailed**: Directional claim (e.g., is mean > μ?)
#    - **Two-tailed**: Non-directional claim (e.g., is mean ≠ μ?)
#
# ---
#
# ### 📌 Decision Rule:
#
# - Calculate the **Z-statistic** using sample data.
# - Compare it with a **critical Z-value** (e.g., ±1.96 for 95% confidence).
# - If it falls in the rejection region, **reject the null hypothesis (H₀)**.
#
# ---
# ### 16. How Do You Calculate a Z-Score, and What Does It Represent?
#
# A **Z-score** tells you **how many standard deviations** a data point is from the **mean** of the distribution.
#
# ---
#
# ### ✅ Z-Score Formula:
#
# For a **single data point** \( X \):
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# For a **sample mean** \( \bar{X} \) (when sampling distribution is used):
#
# $$
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# $$
#
# ---
#
# ### 🧠 What It Represents:
#
# - **Z = 0** → The value is exactly at the mean
# - **Z > 0** → The value is above the mean
# - **Z < 0** → The value is below the mean
# - It helps compare values **from different distributions** or **detect outliers**
#
# ---
#
# ### 📊 Practical Use:
#
# Z-scores are used in:
# - **Standardization** of datasets
# - **Hypothesis testing**
# - **Confidence interval** calculation
# - **Detecting outliers** (e.g., if \( |Z| > 2 \), the point may be unusual)
#
# ---
# ### 17. What Are Point Estimates and Interval Estimates in Statistics?
#
# In statistics, we often use sample data to **estimate population parameters** (like mean or proportion). There are two main types of estimates:
#
# ---
#
# ### ✅ 1. Point Estimate
#
# - A **single value** used to estimate a population parameter.
# - Example: Using the **sample mean ( \( \bar{X} \) )** to estimate the population mean \( \mu \).
#
# #### 📌 Example:
# > If you measure the average height of 30 students and get 165 cm,
# > then **165 cm is the point estimate** of the population mean height.
#
# ---
#
# ### ✅ 2. Interval Estimate (Confidence Interval)
#
# - Provides a **range of values** likely to contain the population parameter.
# - More informative than a point estimate because it includes **uncertainty**.
# - Usually written as:
#
# $$
# \text{Confidence Interval} = \bar{X} \pm Z \cdot \frac{\sigma}{\sqrt{n}}
# $$
#
# Where:
#
# $$
# \bar{X} = \text{Sample mean}
# $$
#
# $$
# Z = \text{Z-score for the desired confidence level (e.g., 1.96 for 95%)}
# $$
#
# $$
# \sigma = \text{Population standard deviation}
# $$
#
# $$
# n = \text{Sample size}
# $$
#
# ### 18. What is the Significance of Confidence Intervals in Statistical Analysis?
#
# A **confidence interval (CI)** is a range of values, derived from sample data, that is likely to contain the true value of an unknown **population parameter** (like mean or proportion) with a specified level of confidence (e.g., 95%).
#
# ---
#
# ### ✅ Why Confidence Intervals Matter:
#
# 1. **Incorporate Uncertainty**
#    - CIs reflect the **natural variability** in sample data and give a **range** instead of a single point.
#
# 2. **More Informative Than Point Estimates**
#    - A point estimate (like a sample mean) is just a guess. A CI gives a **margin of error** around that guess.
#
# 3. **Allow Decision-Making with Risk Awareness**
#    - Helps researchers and policymakers understand **how precise** their estimates are.
#
# 4. **Used in Hypothesis Testing**
#    - If a hypothesized value (e.g., population mean) **falls outside the CI**, it may be **rejected**.
#
# 5. **Communicate Statistical Results Clearly**
#    - A 95% CI means that if we repeated the experiment many times, **95% of those intervals would contain the true parameter**.
#
# ---
#
# ### 📘 Example:
#
# - Suppose the average test score from a sample of students is 80, and the 95% confidence interval is (77.5, 82.5).
# - This means we're 95% confident the true average score of **all students** lies between **77.5 and 82.5**.
#
# ---
# ### 19. What is the Relationship Between a Z-score and a Confidence Interval?
#
# A **Z-score** and a **confidence interval** are closely related because:
#
# ✅ The Z-score determines **how far** from the sample mean we need to go to capture a specific percentage of the **sampling distribution**.
#
# ---
#
# ### ✅ Formula:
#
# $$
# \text{Confidence Interval} = \bar{X} \pm Z \cdot \frac{\sigma}{\sqrt{n}}
# $$
#
# Where:
#
# $$
# \bar{X} = \text{Sample mean}
# $$
#
# $$
# Z = \text{Z-score based on the desired confidence level}
# $$
#
# $$
# \sigma = \text{Population standard deviation}
# $$
#
# $$
# n = \text{Sample size}
# $$
#
# ---
#
# ### 📌 Z-score Values for Common Confidence Levels:
#
# | Confidence Level | Z-score (±) |
# |------------------|-------------|
# | 90%              | 1.645       |
# | 95%              | 1.96        |
# | 99%              | 2.576       |
#
# The Z-score is chosen based on the **desired confidence level**, and it determines the **width** of the confidence interval.
#
# ---
# ### 20. How Are Z-Scores Used to Compare Different Distributions?
#
# **Z-scores** allow us to compare values from **different distributions** by **standardizing** them.
#
# ---
#
# ### ✅ What Does a Z-Score Do?
#
# A **Z-score** tells us how far a data point is from the **mean**, measured in **standard deviations**:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
#
# $$
# X = \text{The data point}
# $$
#
# $$
# \mu = \text{The mean of the distribution}
# $$
#
# $$
# \sigma = \text{The standard deviation}
# $$
#
# ---
#
# ### 📘 Why Use Z-Scores to Compare?
#
# Different datasets might have:
# - Different **means**
# - Different **scales**
# - Different **standard deviations**
#
# Z-scores **standardize** the data, converting them to a **common scale** with:
# - Mean = 0
# - Standard deviation = 1
#
# ---
#
# ### 📊 Example:
#
# | Student | Test Score | Subject | Mean | Std Dev | Z-score |
# |---------|------------|---------|------|---------|---------|
# | Alice   | 85         | Math    | 70   | 10      | 1.5     |
# | Bob     | 78         | Science | 60   | 12      | 1.5     |
#
# Both students have the **same Z-score (1.5)**, meaning they performed **equally well relative to their class**, even though the scores and subjects differ.
#
# ---
# ### 21. What Are the Assumptions for Applying the Central Limit Theorem (CLT)?
#
# The **Central Limit Theorem (CLT)** states that the sampling distribution of the sample mean approaches a **normal distribution** as the sample size becomes large — **regardless of the shape of the population**.
#
# However, there are a few important **assumptions** to apply CLT correctly:
#
# ---
#
# ### ✅ Key Assumptions:
#
# 1. **Random Sampling**
#    - The samples should be drawn **randomly** from the population.
#
# 2. **Independence**
#    - Observations must be **independent** of each other.
#    - If sampling without replacement, the sample size should be **less than 10% of the population** to ensure approximate independence.
#
# 3. **Sample Size is Sufficiently Large**
#    - If the population is **not normally distributed**, a **larger sample size** is needed (commonly **n ≥ 30**).
#    - If the population **is normal**, smaller sample sizes are acceptable.
#
# 4. **Finite Variance**
#    - The population from which the samples are drawn must have a **finite standard deviation** (i.e., no infinite values or extreme outliers dominating the data).
#
# ---
#
# ### 🧠 Summary Table:
#
# | Assumption              | Why It Matters                          |
# |-------------------------|------------------------------------------|
# | Random Sampling         | Avoids bias in estimation                |
# | Independence            | Ensures valid distribution behavior      |
# | Large Enough Sample     | Enables approximation to normality       |
# | Finite Variance         | Keeps sampling distribution stable       |
#
# ---
#
# ### 📘 Example:
#
# - If you're drawing student test scores from a skewed population, you need **n ≥ 30** to trust that the sample mean will behave normally.
#
# ---
# ### 22. What is the Concept of Expected Value in a Probability Distribution?
#
# The **expected value** (or **mean**) of a random variable is the **long-run average outcome** you'd expect if an experiment were repeated many times.
#
# ---
#
# ### ✅ Definition:
#
# For a **discrete** random variable:
#
# Let the values be:
#
# $$
# x_1, x_2, \ldots, x_n
# $$
#
# with corresponding probabilities:
#
# $$
# P(x_1), P(x_2), \ldots, P(x_n)
# $$
#
# Then the **expected value** is calculated as:
#
# $$
# E(X) = \sum_{i=1}^{n} x_i \cdot P(x_i)
# $$
#
# For a **continuous** random variable with probability density function \( f(x) \):
#
# $$
# E(X) = \int_{-\infty}^{\infty} x \cdot f(x) \, dx
# $$
#
# ---
#
# ### 🧠 Interpretation:
#
# - The expected value is **not necessarily an outcome** itself.
# - It's a **weighted average** of all possible outcomes.
# - Think of it as the **"center of mass"** of the distribution.
#
# ---
#
# ### 📘 Example (Discrete):
#
# > Suppose you roll a fair 6-sided die. The expected value is:
#
# $$
# E(X) = \frac{1+2+3+4+5+6}{6} = 3.5
# $$
#
# > You never actually roll a 3.5 — but that's the average **in the long run**.
#
# ---
# ### 23. How Does a Probability Distribution Relate to the Expected Outcome of a Random Variable?
#
# A **probability distribution** tells us the **likelihood** of each possible outcome of a **random variable**.
#
# The **expected outcome** (or **expected value**) is the **weighted average** of all those possible outcomes, where each outcome is weighted by its probability from the distribution.
#
# ---
#
# ### ✅ Relationship Explained:
#
# - The **probability distribution** provides:
#   - All possible values a random variable can take
#   - The **probability** associated with each value
#
# - The **expected value** is calculated using the distribution as:
#
# $$
# E(X) = \sum_{i=1}^{n} x_i \cdot P(x_i)
# \quad \text{(discrete case)}
# $$
#
# or
#
# $$
# E(X) = \int_{-\infty}^{\infty} x \cdot f(x) \, dx
# \quad \text{(continuous case)}
# $$
#
# ---
#
# ### 📘 Example:
#
# > A loaded die gives these probabilities:
# > - 1 with 0.1, 2 with 0.1, 3 with 0.2, 4 with 0.2, 5 with 0.2, 6 with 0.2
# > Then the **expected value** is:
#
# $$
# E(X) = 1(0.1) + 2(0.1) + 3(0.2) + 4(0.2) + 5(0.2) + 6(0.2) = 4.2
# $$
#
# This value comes directly from **applying the probability distribution** to the variable’s possible outcomes.
#
# #Pratical questions :-
#
# ###1.Write a Python program to generate a random variable and display its value.

# %%
# Import required libraries
import numpy as np
import random
import matplotlib.pyplot as plt

# -------------------------------
# 1. Generate a Discrete Random Variable
# -------------------------------
discrete_random_variable = random.randint(1, 10)  # Random integer from 1 to 10
print("🔢 Discrete Random Variable (1 to 10):", discrete_random_variable)

# -------------------------------
# 2. Generate a Continuous Random Variable (Normal Distribution)
# -------------------------------
continuous_random_variable = np.random.normal(loc=0, scale=1)  # mean=0, std=1
print("📈 Continuous Random Variable from N(0, 1):", continuous_random_variable)

# -------------------------------
# 3. Visualization: Histogram of 1000 Normal Random Values
# -------------------------------
# Generate 1000 values from standard normal distribution
data = np.random.normal(0, 1, 1000)

# Plot the histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Random Variable from N(0, 1)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# 🔢 Discrete Random Variable (1 to 10): 8
# 📈 Continuous Random Variable from N(0, 1): -0.3699073765155143

# %% [markdown]
# ###2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Define discrete uniform distribution (e.g., integers 1 through 6)
# -------------------------------
values = np.arange(1, 7)  # Possible outcomes (like a fair die)
pmf = np.full_like(values, 1/len(values), dtype=float)  # Equal probability for each

# -------------------------------
# 2. Plot the PMF
# -------------------------------
plt.figure(figsize=(7, 4))
plt.stem(values, pmf, basefmt=" ")  # Removed use_line_collection
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.xticks(values)
plt.ylim(0, max(pmf) + 0.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# -------------------------------
# 3. Sample 10 random values from the distribution
# -------------------------------
samples = np.random.choice(values, size=10, replace=True)
print("🎲 Random samples from Discrete Uniform Distribution:", samples)
# Out:
# 🎲 Random samples from Discrete Uniform Distribution: [3 2 2 2 3 4 6 3 3 1]

# %% [markdown]
# ###3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
    x (int): Outcome (must be 0 or 1)
    p (float): Probability of success (0 ≤ p ≤ 1)

    Returns:
    float: Probability of observing x
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")

    return p**x * (1 - p)**(1 - x)

# Example usage
p = 0.7  # Probability of success

print("P(X=0):", bernoulli_pdf(0, p))  # Should return 0.3
print("P(X=1):", bernoulli_pdf(1, p))  # Should return 0.7
# Out:
# P(X=0): 0.30000000000000004
# P(X=1): 0.7

# %% [markdown]
# ###4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for binomial distribution
n = 10          # number of trials
p = 0.5         # probability of success
size = 1000     # number of samples

# Simulate binomial distribution
samples = np.random.binomial(n=n, p=p, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(-0.5, n + 1.5, 1), density=True,
         edgecolor='black', color='skyblue', rwidth=0.9)
plt.title("Binomial Distribution: n = 10, p = 0.5")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(0, n + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ###5.Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lam = 4           # λ = average rate (mean)
size = 1000       # number of samples

# Generate Poisson-distributed data
data = np.random.poisson(lam=lam, size=size)

# Get unique values and their frequencies
values, counts = np.unique(data, return_counts=True)
pmf = counts / size  # empirical probabilities

# Plot using stem plot (discrete PMF style)
plt.figure(figsize=(8, 5))
plt.stem(values, pmf, basefmt=" ", linefmt="skyblue", markerfmt="bo")
plt.title(f"Poisson Distribution (λ = {lam})")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ###6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Define a discrete uniform distribution (e.g., integers from 1 to 6)
# -------------------------------
values = np.arange(1, 7)  # Like rolling a fair 6-sided die
prob = 1 / len(values)    # Equal probability for each value

# -------------------------------
# 2. Calculate the Cumulative Distribution Function (CDF)
# -------------------------------
pmf = np.full_like(values, prob, dtype=float)
cdf = np.cumsum(pmf)  # Cumulative sum of PMF

# -------------------------------
# 3. Plot the CDF
# -------------------------------
plt.figure(figsize=(8, 5))
plt.step(values, cdf, where='post', color='darkblue', linewidth=2)
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.ylim(0, 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(values)
plt.show()

# -------------------------------
# 4. Display CDF values
# -------------------------------
for v, c in zip(values, cdf):
    print(f"P(X ≤ {v}) = {c:.2f}")
# Out:
# P(X ≤ 1) = 0.17
# P(X ≤ 2) = 0.33
# P(X ≤ 3) = 0.50
# P(X ≤ 4) = 0.67
# P(X ≤ 5) = 0.83
# P(X ≤ 6) = 1.00

# %% [markdown]
# ###7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Parameters for uniform distribution
# -------------------------------
a = 2   # Lower bound
b = 8   # Upper bound
size = 1000  # Number of random samples

# -------------------------------
# 2. Generate samples from Uniform(a, b)
# -------------------------------
samples = np.random.uniform(low=a, high=b, size=size)

# -------------------------------
# 3. Plot histogram and theoretical PDF
# -------------------------------
plt.figure(figsize=(8, 5))

# Histogram (normalized to show density)
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7, label='Sampled Data')

# Plot theoretical PDF line
plt.hlines(1 / (b - a), a, b, colors='red', linestyles='--', label='Theoretical PDF (f(x) = 1/(b - a))')

plt.title(f"Continuous Uniform Distribution U({a}, {b})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ###8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Parameters for the normal distribution
# -------------------------------
mu = 0      # Mean
sigma = 1   # Standard deviation
size = 1000 # Number of samples

# -------------------------------
# 2. Generate normally distributed data
# -------------------------------
samples = np.random.normal(loc=mu, scale=sigma, size=size)

# -------------------------------
# 3. Plot the histogram
# -------------------------------
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=30, density=True, color='lightgreen', edgecolor='black')
plt.title(f"Normal Distribution (μ = {mu}, σ = {sigma})")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ###9.Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores and plot them for a given dataset.

    Parameters:
    data (list or np.array): Numeric dataset
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    z_scores = (data - mean) / std

    # Print values
    print("Mean:", round(mean, 2))
    print("Standard Deviation:", round(std, 2))
    print("Z-scores:", np.round(z_scores, 2))

    # Plot Z-scores
    plt.figure(figsize=(10, 5))
    plt.bar(range(len(z_scores)), z_scores, color='coral', edgecolor='black')
    plt.axhline(0, color='black', linestyle='--')
    plt.title("Z-scores of Dataset")
    plt.xlabel("Index")
    plt.ylabel("Z-score")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# Example usage
sample_data = [65, 70, 75, 80, 85, 90, 95, 100]
calculate_and_plot_z_scores(sample_data)
# Out:
# Mean: 82.5
# Standard Deviation: 11.46
# Z-scores: [-1.53 -1.09 -0.65 -0.22  0.22  0.65  1.09  1.53]

# %% [markdown]
# ###10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Define a non-normal population (Exponential Distribution)
# -------------------------------
population = np.random.exponential(scale=2.0, size=100000)

# -------------------------------
# 2. Simulate sampling from the population
# -------------------------------
sample_size = 30         # Each sample has 30 observations
num_samples = 1000       # Number of samples to draw
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=True)
    sample_means.append(np.mean(sample))

# -------------------------------
# 3. Plot the results
# -------------------------------
plt.figure(figsize=(14, 5))

# Plot original (skewed) population
plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='orange', edgecolor='black', density=True)
plt.title("Original Population (Exponential Distribution)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.5)

# Plot histogram of sample means (CLT result)
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title(f"Sampling Distribution of Mean\n(n = {sample_size}, samples = {num_samples})")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Parameters
# -------------------------------
population_mean = 50
population_std = 10
sample_size = 30
num_samples = 1000

# -------------------------------
# 2. Generate samples from a normal distribution
# -------------------------------
sample_means = []

for _ in range(num_samples):
    sample = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# -------------------------------
# 3. Plot the sampling distribution of the sample means
# -------------------------------
plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=30, color='lightblue', edgecolor='black', density=True)
plt.title(f"CLT Verification Using Normal Distribution\n(n = {sample_size}, Samples = {num_samples})")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ###12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Plots the standard normal distribution (mean = 0, std = 1).
    """
    # Generate values from -4 to 4 (covers most of the standard normal)
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, loc=0, scale=1)  # PDF for N(0, 1)

    # Plot the curve
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='darkblue', linewidth=2, label='PDF of N(0, 1)')
    plt.fill_between(x, y, color='skyblue', alpha=0.3)
    plt.title("Standard Normal Distribution (μ = 0, σ = 1)")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# ###13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# -------------------------------
# 1. Define parameters
# -------------------------------
n = 10        # Number of trials
p = 0.5       # Probability of success
size = 10     # Number of random variables to generate

# -------------------------------
# 2. Generate random binomial variables
# -------------------------------
random_vars = np.random.binomial(n=n, p=p, size=size)
print("🎲 Random binomial variables:", random_vars)

# -------------------------------
# 3. Calculate PMF (probability of each observed value)
# -------------------------------
pmf_values = binom.pmf(random_vars, n, p)
print("\n🔢 Corresponding probabilities (PMF):")
for val, prob in zip(random_vars, pmf_values):
    print(f"P(X = {val}) = {prob:.4f}")

# -------------------------------
# 4. Optional: Plot the full Binomial PMF
# -------------------------------
x = np.arange(0, n + 1)
y = binom.pmf(x, n, p)

plt.figure(figsize=(8, 5))
plt.stem(x, y, basefmt=" ")
plt.title(f"Binomial Distribution PMF (n = {n}, p = {p})")
plt.xlabel("Number of Successes (X)")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# 🎲 Random binomial variables: [8 5 7 4 7 2 7 5 4 0]
#
# 🔢 Corresponding probabilities (PMF):
# P(X = 8) = 0.0439
# P(X = 5) = 0.2461
# P(X = 7) = 0.1172
# P(X = 4) = 0.2051
# P(X = 7) = 0.1172
# P(X = 2) = 0.0439
# P(X = 7) = 0.1172
# P(X = 5) = 0.2461
# P(X = 4) = 0.2051
# P(X = 0) = 0.0010

# %% [markdown]
# ###14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mu, sigma):
    """
    Calculate Z-score for a given data point x.
    """
    z = (x - mu) / sigma
    return z

# -------------------------------
# Example values
# -------------------------------
x = 75           # data point
mu = 60          # population mean
sigma = 10       # population standard deviation

# -------------------------------
# Calculate Z-score
# -------------------------------
z = calculate_z_score(x, mu, sigma)
print(f"Z-score for x = {x} is: {z:.2f}")

# -------------------------------
# Plot Standard Normal Distribution with Z-score
# -------------------------------
x_vals = np.linspace(-4, 4, 1000)
y_vals = norm.pdf(x_vals, 0, 1)

plt.figure(figsize=(10, 5))
plt.plot(x_vals, y_vals, label='Standard Normal PDF', color='blue')

# Fill area up to the Z-score
plt.fill_between(x_vals, y_vals, where=(x_vals <= z), color='skyblue', alpha=0.5, label=f'P(Z ≤ {z:.2f})')

# Mark the Z-score
plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')

plt.title("Z-score Compared to Standard Normal Distribution")
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()
# Out:
# Z-score for x = 75 is: 1.50

# %% [markdown]
# ###15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# -------------------------------
# 1. Sample data and population parameters
# -------------------------------
sample_data = [52, 48, 50, 47, 51, 49, 53, 46, 50, 49]
mu_0 = 50         # Hypothesized population mean (null)
sigma = 2         # Known population standard deviation
alpha = 0.05      # Significance level

# -------------------------------
# 2. Compute test statistic (Z)
# -------------------------------
sample_mean = np.mean(sample_data)
n = len(sample_data)

z = (sample_mean - mu_0) / (sigma / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))  # two-tailed test

# -------------------------------
# 3. Output the results
# -------------------------------
print("Sample Mean:", round(sample_mean, 2))
print("Z-Statistic:", round(z, 3))
print("P-value:", round(p_value, 4))

# -------------------------------
# 4. Decision
# -------------------------------
if p_value < alpha:
    print("❌ Reject the Null Hypothesis (Significant Difference)")
else:
    print("✅ Fail to Reject the Null Hypothesis (No Significant Difference)")
# Out:
# Sample Mean: 49.5
# Z-Statistic: -0.791
# P-value: 0.4292
# ✅ Fail to Reject the Null Hypothesis (No Significant Difference)

# %% [markdown]
# ###16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy.stats import norm

# -------------------------------
# 1. Sample data and parameters
# -------------------------------
data = [52, 48, 50, 47, 51, 49, 53, 46, 50, 49]
sigma = 2         # Known population standard deviation
confidence = 0.95 # Confidence level

# -------------------------------
# 2. Compute sample statistics
# -------------------------------
n = len(data)
sample_mean = np.mean(data)
z_score = norm.ppf(1 - (1 - confidence) / 2)

margin_of_error = z_score * (sigma / np.sqrt(n))
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# -------------------------------
# 3. Display result
# -------------------------------
print(f"Sample Mean = {sample_mean:.2f}")
print(f"{int(confidence * 100)}% Confidence Interval: [{ci_lower:.2f}, {ci_upper:.2f}]")

# -------------------------------
# 4. Interpretation
# -------------------------------
print(f"\nInterpretation:")
print(f"We are {int(confidence * 100)}% confident that the true population mean lies between {ci_lower:.2f} and {ci_upper:.2f}.")
# Out:
# Sample Mean = 49.50
# 95% Confidence Interval: [48.26, 50.74]
#
# Interpretation:
# We are 95% confident that the true population mean lies between 48.26 and 50.74.

# %% [markdown]
# ###17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# -------------------------------
# 1. Generate data from a normal distribution
# -------------------------------
mu = 100       # population mean
sigma = 15     # population standard deviation
n = 50         # sample size

np.random.seed(1)  # for reproducibility
sample = np.random.normal(loc=mu, scale=sigma, size=n)

# -------------------------------
# 2. Calculate sample statistics
# -------------------------------
sample_mean = np.mean(sample)
sample_std = sigma  # known population std deviation

# Confidence level
confidence = 0.95
z = norm.ppf(1 - (1 - confidence) / 2)

# Margin of error
margin_of_error = z * (sample_std / np.sqrt(n))

# Confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# -------------------------------
# 3. Print results
# -------------------------------
print(f"Sample Mean: {sample_mean:.2f}")
print(f"{int(confidence * 100)}% Confidence Interval: [{ci_lower:.2f}, {ci_upper:.2f}]")

# -------------------------------
# 4. Interpretation
# -------------------------------
print(f"\nInterpretation:")
print(f"We are {int(confidence * 100)}% confident that the true population mean lies between {ci_lower:.2f} and {ci_upper:.2f}.")

# -------------------------------
# 5. Optional: Plot the CI
# -------------------------------
plt.figure(figsize=(8, 2))
plt.axvline(mu, color='green', linestyle='--', label='True Mean (μ)')
plt.errorbar(sample_mean, 0.5, xerr=margin_of_error, fmt='o', color='red', capsize=5, label='Confidence Interval')
plt.title("Confidence Interval for Sample Mean")
plt.yticks([])
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Sample Mean: 99.62
# 95% Confidence Interval: [95.46, 103.77]
#
# Interpretation:
# We are 95% confident that the true population mean lies between 95.46 and 103.77.

# %% [markdown]
# ###18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# -------------------------------
# 1. Define parameters of the normal distribution
# -------------------------------
mu = 100       # Mean
sigma = 15     # Standard deviation

# -------------------------------
# 2. Generate x values and calculate PDF
# -------------------------------
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf = norm.pdf(x, loc=mu, scale=sigma)

# -------------------------------
# 3. Plot the PDF
# -------------------------------
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='darkblue', linewidth=2, label=f'N({mu}, {sigma}²)')
plt.fill_between(x, pdf, color='lightblue', alpha=0.4)
plt.title("Probability Density Function of Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ###19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# -------------------------------
# 1. Define Poisson distribution parameters
# -------------------------------
lam = 4  # λ = average rate (e.g., 4 events per interval)
x_values = np.arange(0, 15)  # Values to evaluate CDF for

# -------------------------------
# 2. Calculate CDF values
# -------------------------------
cdf_values = poisson.cdf(x_values, mu=lam)

# -------------------------------
# 3. Print CDF table
# -------------------------------
print("Poisson CDF (λ = 4):")
for x, cdf in zip(x_values, cdf_values):
    print(f"P(X ≤ {x}) = {cdf:.4f}")

# -------------------------------
# 4. Plot the CDF
# -------------------------------
plt.figure(figsize=(8, 5))
plt.step(x_values, cdf_values, where='post', color='purple', linewidth=2)
plt.title("Cumulative Distribution Function (CDF) of Poisson(λ = 4)")
plt.xlabel("X (Number of Events)")
plt.ylabel("P(X ≤ x)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, 1.05)
plt.show()
# Out:
# Poisson CDF (λ = 4):
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# ###20.Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# -------------------------------
# 1. Parameters for uniform distribution
# -------------------------------
a = 5   # Lower bound
b = 15  # Upper bound
size = 10000  # Number of samples

# -------------------------------
# 2. Simulate random variable from Uniform(a, b)
# -------------------------------
samples = np.random.uniform(low=a, high=b, size=size)

# -------------------------------
# 3. Calculate expected value
# -------------------------------
theoretical_mean = (a + b) / 2
sample_mean = np.mean(samples)

# -------------------------------
# 4. Display results
# -------------------------------
print(f"Theoretical Expected Value (E[X]) = ({a} + {b}) / 2 = {theoretical_mean}")
print(f"Sample Mean from simulation ≈ {sample_mean:.2f}")
# Out:
# Theoretical Expected Value (E[X]) = (5 + 15) / 2 = 10.0
# Sample Mean from simulation ≈ 9.99

# %% [markdown]
# ###21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Define two datasets
# -------------------------------
data1 = [12, 15, 14, 10, 13, 18, 20, 17]
data2 = [5, 25, 7, 30, 9, 3, 22, 35]

# -------------------------------
# 2. Calculate standard deviations
# -------------------------------
std1 = np.std(data1, ddof=1)  # sample standard deviation
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# -------------------------------
# 3. Visualize the comparison
# -------------------------------
labels = ['Dataset 1', 'Dataset 2']
std_values = [std1, std2]

plt.figure(figsize=(6, 4))
plt.bar(labels, std_values, color=['skyblue', 'salmon'], edgecolor='black')
plt.title("Comparison of Standard Deviations")
plt.ylabel("Standard Deviation")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.ylim(0, max(std_values) + 5)

# Annotate values
for i, v in enumerate(std_values):
    plt.text(i, v + 0.5, f"{v:.2f}", ha='center', fontweight='bold')

plt.show()
# Out:
# Standard Deviation of Dataset 1: 3.31
# Standard Deviation of Dataset 2: 12.46

# %% [markdown]
# ###22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Generate data from a normal distribution
# -------------------------------
mu = 50       # mean
sigma = 10    # standard deviation
size = 1000   # number of data points

np.random.seed(42)
data = np.random.normal(loc=mu, scale=sigma, size=size)

# -------------------------------
# 2. Calculate Range and IQR
# -------------------------------
data_range = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# -------------------------------
# 3. Print Results
# -------------------------------
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")

# -------------------------------
# 4. Optional: Boxplot for Visualization
# -------------------------------
plt.figure(figsize=(6, 4))
plt.boxplot(data, vert=False)
plt.title("Boxplot of Normally Distributed Data")
plt.xlabel("Value")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Range: 70.94
# Interquartile Range (IQR): 12.96
# Q1 (25th percentile): 43.52
# Q3 (75th percentile): 56.48

# %% [markdown]
# ###23. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1. Generate sample dataset
# -------------------------------
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=1000)  # Normal distribution

# -------------------------------
# 2. Z-score normalization
# -------------------------------
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# -------------------------------
# 3. Print stats
# -------------------------------
print(f"Original Mean: {mean:.2f}, Std Dev: {std:.2f}")
print(f"Z-Score Mean (should be ≈ 0): {np.mean(z_scores):.2f}")
print(f"Z-Score Std Dev (should be ≈ 1): {np.std(z_scores):.2f}")

# -------------------------------
# 4. Plot before and after normalization
# -------------------------------
plt.figure(figsize=(12, 5))

# Original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)

# Normalized data
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='salmon', edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 99.32, Std Dev: 14.81
# Z-Score Mean (should be ≈ 0): -0.00
# Z-Score Std Dev (should be ≈ 1): 1.00

# %% [markdown]
# ###24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_normal_distribution_skew_kurt(mu=0, sigma=1, size=1000):
    """
    Generates data from a normal distribution and calculates skewness and kurtosis.

    Parameters:
        mu (float): Mean of the distribution
        sigma (float): Standard deviation
        size (int): Number of data points to generate

    Returns:
        dict: Contains skewness and kurtosis values
    """
    # Generate data
    data = np.random.normal(loc=mu, scale=sigma, size=size)

    # Calculate skewness and kurtosis
    data_skew = skew(data)
    data_kurtosis = kurtosis(data, fisher=True)  # Fisher=True gives 0 for normal

    # Display results
    print(f"Mean: {np.mean(data):.2f}, Std Dev: {np.std(data):.2f}")
    print(f"Skewness: {data_skew:.4f} (≈ 0 means symmetric)")
    print(f"Kurtosis: {data_kurtosis:.4f} (≈ 0 means normal-like)")

    return {"skewness": data_skew, "kurtosis": data_kurtosis}

# -------------------------------
# Call the function
# -------------------------------
analyze_normal_distribution_skew_kurt(mu=100, sigma=15, size=1000)
# Out:
# Mean: 100.20, Std Dev: 14.52
# Skewness: 0.0556 (≈ 0 means symmetric)
# Kurtosis: -0.1075 (≈ 0 means normal-like)
# {'skewness': np.float64(0.055647222974737114),
#  'kurtosis': np.float64(-0.1074540280891263)}
